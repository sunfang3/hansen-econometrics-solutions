# %% [markdown]
# # Hansen Ch.5 习题解答
#
# 理论全文见 `Hansen_Ch05_Exercises_Solutions.md`。
#
# 本 notebook 做 **Exercise 5.1** 模拟核对。

# %%
import numpy as np
rng = np.random.default_rng(0)
r = 5
Z = rng.normal(size=(200000, r))
Q = np.sum(Z**2, axis=1)
print("E[Q] sample", Q.mean(), "theory", r)
print("Var[Q] sample", Q.var(ddof=1), "theory", 2*r)

# %% [markdown]
# ## 其余题目（5.2–5.12）
#
# 均为正态回归代数/信息界证明，详见 markdown：
#
# - 5.2–5.3 正态线性变换
# - 5.4 似然与对数似然同最大点
# - 5.5 $\hat Y_i\mid X\sim N(X_i'\beta,\sigma^2 h_{ii})$
# - 5.6–5.7 残差/HC 与 $\hat\beta$ 条件独立
# - 5.8 对称分布 $F(-u)=1-F(u)$
# - 5.9 单调变换保持置信区间覆盖
# - 5.10 LR 与 $F$ 拒绝域可对齐
# - 5.11 信息阵 (5.20)
# - 5.12 $\mathrm{var}(s^2)=2\sigma^4/(n-k)>$ CRLB
